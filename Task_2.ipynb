# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris=load_iris()
df=pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target']=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='viridis', marker='o')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='Blues', marker='o')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='cividis', marker='*')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='spring', marker='x')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='coolwarm', marker='P')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='plasma', marker='<')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='YlOrBr', marker='o')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='inferno', marker='o')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='cool', marker='>')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'], cmap='Spectral', marker='.')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()
